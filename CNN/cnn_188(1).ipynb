# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

np.random.seed(42)
tf.random.set_seed(42)

# %%
print("TensorFlow version:", tf.__version__)
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPUs detected:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.19.0
# Built with CUDA: True
# GPUs detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from tensorflow import keras
from tensorflow.keras import layers, models

def create_cnn_model(input_shape=(19, 19, 1), learning_rate=0.001):

    model = models.Sequential([
        keras.Input(shape=input_shape),

        #First convolutional block
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2)),
        layers.Dropout(0.25),

        #Flatten + Dense layers
        layers.Flatten(),
        layers.Dense(128, activation='relu'),
        layers.BatchNormalization(),
        layers.Dropout(0.5),


        # Output layer
        layers.Dense(1, activation='sigmoid')
    ])

    optimizer = keras.optimizers.Adam(learning_rate=learning_rate)

    model.compile(
        optimizer=optimizer,
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    return model



def plot_training_history(history):

    fig, axes = plt.subplots(1, 2, figsize=(14, 5))

    # Plot accuracy
    axes[0].plot(history.history['accuracy'], label='Train Accuracy')
    axes[0].plot(history.history['val_accuracy'], label='Val Accuracy')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Accuracy')
    axes[0].set_title('Model Accuracy')
    axes[0].legend(fontsize=10)


    # Plot loss
    axes[1].plot(history.history['loss'], label='Train Loss')
    axes[1].plot(history.history['val_loss'], label='Val Loss')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Loss')
    axes[1].set_title('Model Loss')
    axes[1].legend(fontsize=10)


    plt.tight_layout()
    plt.show()


def plot_confusion_matrix(y_true, y_pred, class_names=None):

    cm = confusion_matrix(y_true, y_pred)

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names,
                cbar_kws={'label': 'Count'})
    plt.xlabel('Predicted Label', fontsize=12)
    plt.ylabel('True Label', fontsize=12)
    plt.title('Confusion Matrix', fontsize=14, fontweight='bold')
    plt.tight_layout()
    plt.show()


def evaluate_model(model, X_test, y_test, class_names=None):

    y_pred_proba = model.predict(X_test, verbose=0)
    if len(y_pred_proba.shape) > 1 and y_pred_proba.shape[1] > 1:
        y_pred = np.argmax(y_pred_proba, axis=1)
    else:
        y_pred = (y_pred_proba > 0.5).astype(int).flatten()


    accuracy = accuracy_score(y_test, y_pred)
    print(f"Test Accuracy: {accuracy:.4f}\n")

    print(classification_report(y_test, y_pred, target_names=class_names))

    plot_confusion_matrix(y_test, y_pred, class_names)

    return y_pred

# %%
from google.colab import drive

#add data to drive and keep in folder and name it data
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
H_train_data  = np.load("drive/MyDrive/new_data/H_train_data.npy", allow_pickle=True)
MDD_train_data = np.load("drive/MyDrive/new_data/MDD_train_data.npy", allow_pickle=True)

H_test_data   = np.load("drive/MyDrive/new_data/H_test_data.npy", allow_pickle=True)
MDD_test_data = np.load("drive/MyDrive/new_data/MDD_test_data.npy", allow_pickle=True)

H_val_data  = np.load("drive/MyDrive/new_data/H_val_data.npy", allow_pickle=True)
MDD_val_data = np.load("drive/MyDrive/new_data/MDD_val_data.npy", allow_pickle=True)

print("H_train_data:", H_train_data.shape)
print("MDD_train_data:", MDD_train_data.shape)
print("H_test_data:", H_test_data.shape)
print("MDD_test_data:", MDD_test_data.shape)
print("H_val_data:", H_val_data.shape)
print("MDD_val_data:", MDD_val_data.shape)

X_train = np.concatenate([H_train_data, MDD_train_data], axis=0)
X_test  = np.concatenate([H_test_data, MDD_test_data], axis=0)
X_val   = np.concatenate([H_val_data, MDD_val_data], axis=0)

y_train = np.concatenate([np.zeros(len(H_train_data)), np.ones(len(MDD_train_data))])
y_test  = np.concatenate([np.zeros(len(H_test_data)),  np.ones(len(MDD_test_data))])
y_val   = np.concatenate([np.zeros(len(H_val_data)), np.ones(len(MDD_val_data))])

print("X_train:", X_train.shape)
print("y_train:", y_train.shape)
print("X_val:", X_val.shape)
print("y_val:", y_val.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)

# Add channel dimension
X_train = X_train[..., np.newaxis].astype(np.float32)
X_val   = X_val[..., np.newaxis].astype(np.float32)
X_test  = X_test[..., np.newaxis].astype(np.float32)  # updated to new test set

print("X_train_new:", X_train.shape)
print("y_train_new:", y_train.shape)
print("X_val:", X_val.shape)
print("y_val:", y_val.shape)
print("X_test:", X_test.shape)
print("y_test:", y_test.shape)
# Out:
# H_train_data: (14557, 19, 19)
# MDD_train_data: (13879, 19, 19)
# H_test_data: (1807, 19, 19)
# MDD_test_data: (2052, 19, 19)
# H_val_data: (1193, 19, 19)
# MDD_val_data: (2389, 19, 19)
# X_train: (28436, 19, 19)
# y_train: (28436,)
# X_val: (3582, 19, 19)
# y_val: (3582,)
# X_test: (3859, 19, 19)
# y_test: (3859,)
# X_train_new: (28436, 19, 19, 1)
# y_train_new: (28436,)
# X_val: (3582, 19, 19, 1)
# y_val: (3582,)
# X_test: (3859, 19, 19, 1)
# y_test: (3859,)

# %%
# Create
model = create_cnn_model(learning_rate=0.001)
model.summary()

# Callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=40,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.4,
        patience=5,
        min_lr=1e-7,
        verbose=1
    )
]

# Train model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=50,
    batch_size=32,
    callbacks=callbacks,
    verbose=1,
)

# Plot training history
plot_training_history(history)

# Evaluate on the updated test set
class_names = ['H', 'MDD']
y_pred = evaluate_model(model, X_test, y_test, class_names)

# Save model
import os
from datetime import datetime

save_dir = "/content/drive/MyDrive/phys188models"
os.makedirs(save_dir, exist_ok=True)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
model_path = f"{save_dir}/granger_cnn_model_{timestamp}.keras"
model.save(model_path)

print(f"Model saved as: {model_path}")
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 19, 19, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 19, 19, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 9, 9, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9, 9, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2592)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       331,904 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 332,993 (1.27 MB)
#  Trainable params: 332,673 (1.27 MB)
#  Non-trainable params: 320 (1.25 KB)
# Epoch 1/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 11s 6ms/step - accuracy: 0.6814 - loss: 0.6336 - val_accuracy: 0.6273 - val_loss: 0.8289 - learning_rate: 0.0010
# Epoch 2/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7756 - loss: 0.4677 - val_accuracy: 0.6173 - val_loss: 0.7963 - learning_rate: 0.0010
# Epoch 3/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8047 - loss: 0.4134 - val_accuracy: 0.5025 - val_loss: 0.9815 - learning_rate: 0.0010
# Epoch 4/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8268 - loss: 0.3763 - val_accuracy: 0.5078 - val_loss: 1.2494 - learning_rate: 0.0010
# Epoch 5/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8510 - loss: 0.3334 - val_accuracy: 0.5438 - val_loss: 1.0398 - learning_rate: 0.0010
# Epoch 6/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8673 - loss: 0.2982 - val_accuracy: 0.5494 - val_loss: 0.9613 - learning_rate: 0.0010
# Epoch 7/50
# 880/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8793 - loss: 0.2713
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0004000000189989805.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8793 - loss: 0.2712 - val_accuracy: 0.5533 - val_loss: 1.1295 - learning_rate: 0.0010
# Epoch 8/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8932 - loss: 0.2509 - val_accuracy: 0.5994 - val_loss: 0.9982 - learning_rate: 4.0000e-04
# Epoch 9/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9043 - loss: 0.2247 - val_accuracy: 0.5999 - val_loss: 1.0609 - learning_rate: 4.0000e-04
# Epoch 10/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9075 - loss: 0.2213 - val_accuracy: 0.6050 - val_loss: 1.0989 - learning_rate: 4.0000e-04
# Epoch 11/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9135 - loss: 0.2025 - val_accuracy: 0.5974 - val_loss: 1.0844 - learning_rate: 4.0000e-04
# Epoch 12/50
# 879/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9220 - loss: 0.1896
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.00016000000759959222.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9220 - loss: 0.1895 - val_accuracy: 0.6125 - val_loss: 1.1013 - learning_rate: 4.0000e-04
# Epoch 13/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9235 - loss: 0.1805 - val_accuracy: 0.6047 - val_loss: 1.1098 - learning_rate: 1.6000e-04
# Epoch 14/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9336 - loss: 0.1678 - val_accuracy: 0.5946 - val_loss: 1.1520 - learning_rate: 1.6000e-04
# Epoch 15/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9281 - loss: 0.1690 - val_accuracy: 0.5994 - val_loss: 1.1828 - learning_rate: 1.6000e-04
# Epoch 16/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9331 - loss: 0.1579 - val_accuracy: 0.6039 - val_loss: 1.1424 - learning_rate: 1.6000e-04
# Epoch 17/50
# 866/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9347 - loss: 0.1569
# Epoch 17: ReduceLROnPlateau reducing learning rate to 6.40000042039901e-05.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9348 - loss: 0.1568 - val_accuracy: 0.6100 - val_loss: 1.1765 - learning_rate: 1.6000e-04
# Epoch 18/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9367 - loss: 0.1538 - val_accuracy: 0.5932 - val_loss: 1.2259 - learning_rate: 6.4000e-05
# Epoch 19/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9356 - loss: 0.1502 - val_accuracy: 0.6041 - val_loss: 1.1914 - learning_rate: 6.4000e-05
# Epoch 20/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9390 - loss: 0.1487 - val_accuracy: 0.5994 - val_loss: 1.1950 - learning_rate: 6.4000e-05
# Epoch 21/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9421 - loss: 0.1414 - val_accuracy: 0.5958 - val_loss: 1.2032 - learning_rate: 6.4000e-05
# Epoch 22/50
# 886/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9421 - loss: 0.1408
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.560000284574926e-05.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9421 - loss: 0.1408 - val_accuracy: 0.5955 - val_loss: 1.2389 - learning_rate: 6.4000e-05
# Epoch 23/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9440 - loss: 0.1400 - val_accuracy: 0.5991 - val_loss: 1.2294 - learning_rate: 2.5600e-05
# Epoch 24/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9414 - loss: 0.1432 - val_accuracy: 0.5974 - val_loss: 1.2382 - learning_rate: 2.5600e-05
# Epoch 25/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9437 - loss: 0.1421 - val_accuracy: 0.6022 - val_loss: 1.2238 - learning_rate: 2.5600e-05
# Epoch 26/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9418 - loss: 0.1430 - val_accuracy: 0.5958 - val_loss: 1.2435 - learning_rate: 2.5600e-05
# Epoch 27/50
# 885/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9429 - loss: 0.1370
# Epoch 27: ReduceLROnPlateau reducing learning rate to 1.0240000847261399e-05.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9429 - loss: 0.1370 - val_accuracy: 0.5938 - val_loss: 1.2336 - learning_rate: 2.5600e-05
# Epoch 28/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9438 - loss: 0.1401 - val_accuracy: 0.6016 - val_loss: 1.2432 - learning_rate: 1.0240e-05
# Epoch 29/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9425 - loss: 0.1393 - val_accuracy: 0.6005 - val_loss: 1.2442 - learning_rate: 1.0240e-05
# Epoch 30/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9427 - loss: 0.1399 - val_accuracy: 0.6005 - val_loss: 1.2338 - learning_rate: 1.0240e-05
# Epoch 31/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9437 - loss: 0.1415 - val_accuracy: 0.6005 - val_loss: 1.2318 - learning_rate: 1.0240e-05
# Epoch 32/50
# 868/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9430 - loss: 0.1380
# Epoch 32: ReduceLROnPlateau reducing learning rate to 4.09600033890456e-06.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9430 - loss: 0.1379 - val_accuracy: 0.6008 - val_loss: 1.2431 - learning_rate: 1.0240e-05
# Epoch 33/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9458 - loss: 0.1335 - val_accuracy: 0.6030 - val_loss: 1.2374 - learning_rate: 4.0960e-06
# Epoch 34/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9436 - loss: 0.1380 - val_accuracy: 0.6016 - val_loss: 1.2371 - learning_rate: 4.0960e-06
# Epoch 35/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9473 - loss: 0.1333 - val_accuracy: 0.6016 - val_loss: 1.2449 - learning_rate: 4.0960e-06
# Epoch 36/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9456 - loss: 0.1371 - val_accuracy: 0.6013 - val_loss: 1.2485 - learning_rate: 4.0960e-06
# Epoch 37/50
# 882/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9423 - loss: 0.1384
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1.6384001355618238e-06.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9423 - loss: 0.1384 - val_accuracy: 0.6011 - val_loss: 1.2478 - learning_rate: 4.0960e-06
# Epoch 38/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9439 - loss: 0.1389 - val_accuracy: 0.5999 - val_loss: 1.2482 - learning_rate: 1.6384e-06
# Epoch 39/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9457 - loss: 0.1370 - val_accuracy: 0.5999 - val_loss: 1.2488 - learning_rate: 1.6384e-06
# Epoch 40/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9467 - loss: 0.1327 - val_accuracy: 0.6002 - val_loss: 1.2496 - learning_rate: 1.6384e-06
# Epoch 41/50
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9439 - loss: 0.1377 - val_accuracy: 0.6011 - val_loss: 1.2503 - learning_rate: 1.6384e-06
# Epoch 42/50
# 864/889 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9440 - loss: 0.1359
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.553600542247295e-07.
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9440 - loss: 0.1359 - val_accuracy: 0.6013 - val_loss: 1.2509 - learning_rate: 1.6384e-06
# Epoch 42: early stopping
# Test Accuracy: 0.8106
#
#               precision    recall  f1-score   support
#
#            H       0.72      0.96      0.83      1807
#          MDD       0.95      0.68      0.79      2052
#
#     accuracy                           0.81      3859
#    macro avg       0.84      0.82      0.81      3859
# weighted avg       0.84      0.81      0.81      3859
# Model saved as: /content/drive/MyDrive/phys188models/granger_cnn_model_20251213_191543.keras

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='cnn_architecture.png', show_shapes=True, show_layer_names=True)

# %%
pip install -q -U keras-tuner
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 kB 11.1 MB/s eta 0:00:00

# %%
import keras_tuner as kt

# %%
def build_cnn_model(hp):
    model = keras.Sequential()

    model.add(keras.Input(shape=(19, 19, 1)))

    num_blocks = hp.Int("num_blocks", 1, 4)

    activation = hp.Choice("activation", ["relu"])

    filters_start = hp.Int("filters_start", 16, 128, step=16)

    for i in range(num_blocks):
        filters = filters_start * (2 ** i)

        model.add(layers.Conv2D(
            filters=filters,
            kernel_size=hp.Choice(f"kernel_size_{i}", [1, 5]),
            activation=activation,
            padding="same"
        ))
        model.add(layers.BatchNormalization())


        if hp.Boolean(f"pool_block_{i}"):
            model.add(layers.MaxPooling2D(pool_size=2))


        model.add(layers.Dropout(
            hp.Float(f"dropout_block_{i}", 0.0, 0.5, step=0.1)
        ))

    model.add(layers.Flatten())
    model.add(layers.Dense(
        hp.Int("dense_units", 64, 512, step=64),
        activation=activation
    ))
    model.add(layers.Dropout(
        hp.Float("dense_dropout", 0.0, 0.5, step=0.1)
    ))

    lr = hp.Float("learning_rate", 1e-5, 1e-2, sampling="log")


    optimizer = keras.optimizers.Adam(lr)


    # Output
    model.add(layers.Dense(1, activation="sigmoid"))

    model.compile(
        loss="binary_crossentropy",
        optimizer=optimizer,
        metrics=["accuracy"]
    )

    return model

# %%
tuner = kt.Hyperband(
    build_cnn_model,
    objective="val_accuracy",
    max_epochs=30,
    factor=3,
    directory="hypertuning_results",
    project_name="granger_cnn_12-12"
)


early_stop = keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5
)

tuner.search(
    X_train, y_train,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    epochs=50,
    batch_size=32
)


best_hp = tuner.get_best_hyperparameters(1)[0]
model = tuner.get_best_models(1)[0]

print("Best hyperparameters:")
for hp_name in best_hp.values.keys():
    print(hp_name, ":", best_hp.get(hp_name))
# Out:
# Trial 90 Complete [00h 00m 38s]
# val_accuracy: 0.6049692630767822
#
# Best val_accuracy So Far: 0.6619207262992859
# Total elapsed time: 00h 45m 01s
# Best hyperparameters:
# num_blocks : 3
# activation : relu
# filters_start : 112
# kernel_size_0 : 1
# pool_block_0 : True
# dropout_block_0 : 0.2
# dense_units : 128
# dense_dropout : 0.4
# learning_rate : 0.0012661117584381876
# kernel_size_1 : 1
# pool_block_1 : False
# dropout_block_1 : 0.1
# kernel_size_2 : 1
# pool_block_2 : True
# dropout_block_2 : 0.0
# kernel_size_3 : 1
# pool_block_3 : False
# dropout_block_3 : 0.4
# tuner/epochs : 30
# tuner/initial_epoch : 10
# tuner/bracket : 2
# tuner/round : 2
# tuner/trial_id : 0067

# %%
best_hp = tuner.get_best_hyperparameters(1)[0]
model = tuner.hypermodel.build(best_hp)

early_stop_final = keras.callbacks.EarlyStopping(
    monitor='val_loss',
    patience=8,
    verbose=1
)

history = model.fit(
    X_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    callbacks=[early_stop_final],
    verbose=1
)

plot_training_history(history)

timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
path =  f"{save_dir}/granger_cnn_model_{timestamp}.keras"
model.save(path)
print(f"Model saved as: {path}")

evaluate_model(model, X_test, y_test, class_names=['H', 'MDD'])
# Out:
# Epoch 1/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 14s 9ms/step - accuracy: 0.6019 - loss: 0.8979 - val_accuracy: 0.6427 - val_loss: 0.6853
# Epoch 2/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6393 - loss: 0.6120 - val_accuracy: 0.6209 - val_loss: 0.6938
# Epoch 3/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6488 - loss: 0.6000 - val_accuracy: 0.6262 - val_loss: 0.6907
# Epoch 4/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6518 - loss: 0.6004 - val_accuracy: 0.6298 - val_loss: 0.6967
# Epoch 5/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6562 - loss: 0.5970 - val_accuracy: 0.6097 - val_loss: 0.7076
# Epoch 6/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6638 - loss: 0.5849 - val_accuracy: 0.6150 - val_loss: 0.6987
# Epoch 7/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6729 - loss: 0.5813 - val_accuracy: 0.6362 - val_loss: 0.6839
# Epoch 8/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6703 - loss: 0.5743 - val_accuracy: 0.6318 - val_loss: 0.6943
# Epoch 9/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6796 - loss: 0.5680 - val_accuracy: 0.6474 - val_loss: 0.6762
# Epoch 10/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6824 - loss: 0.5695 - val_accuracy: 0.6346 - val_loss: 0.6900
# Epoch 11/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6824 - loss: 0.5699 - val_accuracy: 0.6474 - val_loss: 0.6716
# Epoch 12/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6915 - loss: 0.5582 - val_accuracy: 0.6535 - val_loss: 0.6697
# Epoch 13/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6948 - loss: 0.5587 - val_accuracy: 0.6491 - val_loss: 0.6746
# Epoch 14/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6923 - loss: 0.5575 - val_accuracy: 0.6452 - val_loss: 0.6770
# Epoch 15/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6929 - loss: 0.5549 - val_accuracy: 0.6521 - val_loss: 0.6643
# Epoch 16/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6971 - loss: 0.5475 - val_accuracy: 0.6683 - val_loss: 0.6666
# Epoch 17/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6954 - loss: 0.5502 - val_accuracy: 0.6491 - val_loss: 0.6721
# Epoch 18/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6978 - loss: 0.5465 - val_accuracy: 0.6717 - val_loss: 0.6619
# Epoch 19/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.6973 - loss: 0.5462 - val_accuracy: 0.6457 - val_loss: 0.6718
# Epoch 20/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7053 - loss: 0.5437 - val_accuracy: 0.6602 - val_loss: 0.6683
# Epoch 21/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7036 - loss: 0.5426 - val_accuracy: 0.6368 - val_loss: 0.6786
# Epoch 22/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7085 - loss: 0.5325 - val_accuracy: 0.6178 - val_loss: 0.6877
# Epoch 23/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7046 - loss: 0.5372 - val_accuracy: 0.6611 - val_loss: 0.6610
# Epoch 24/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7057 - loss: 0.5364 - val_accuracy: 0.6661 - val_loss: 0.6588
# Epoch 25/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7118 - loss: 0.5318 - val_accuracy: 0.6625 - val_loss: 0.6641
# Epoch 26/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7088 - loss: 0.5317 - val_accuracy: 0.6457 - val_loss: 0.6696
# Epoch 27/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7141 - loss: 0.5288 - val_accuracy: 0.6647 - val_loss: 0.6661
# Epoch 28/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7088 - loss: 0.5286 - val_accuracy: 0.6354 - val_loss: 0.6786
# Epoch 29/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7114 - loss: 0.5294 - val_accuracy: 0.6494 - val_loss: 0.6775
# Epoch 30/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7145 - loss: 0.5283 - val_accuracy: 0.6418 - val_loss: 0.6736
# Epoch 31/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7127 - loss: 0.5290 - val_accuracy: 0.6552 - val_loss: 0.6635
# Epoch 32/100
# 889/889 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.7143 - loss: 0.5230 - val_accuracy: 0.6586 - val_loss: 0.6646
# Epoch 32: early stopping
# Test Accuracy: 0.8500
#
#               precision    recall  f1-score   support
#
#            H       0.89      0.78      0.83      1807
#          MDD       0.82      0.91      0.87      2052
#
#     accuracy                           0.85      3859
#    macro avg       0.86      0.85      0.85      3859
# weighted avg       0.85      0.85      0.85      3859
# array([0, 0, 0, ..., 0, 1, 0])
